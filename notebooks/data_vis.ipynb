# %% [markdown]
# ## imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from dotenv import load_dotenv
from pyfiglet import Figlet
load_dotenv()

# Generate random data for the boxplot
np.random.seed(10)  # Seed for reproducibility
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# %%
df = pd.read_csv('../infra/assets/myExport.csv')

# %%
df.columns
# Out:
# Index(['t_stamp', 'HpPressure', 'IpPressure', 'LpPressure', 'WetBulbTemp'], dtype='object')

# %% [markdown]
# ## nulls

# %%
print(df.isnull().sum())
# Out:
# t_stamp        0
# HpPressure     0
# IpPressure     0
# LpPressure     0
# WetBulbTemp    0
# dtype: int64

# %% [markdown]
# ## describe

# %%
print(df.describe(include='all'))
# Out:
#         t_stamp     HpPressure     IpPressure     LpPressure    WetBulbTemp
# count    351481  351481.000000  351481.000000  351481.000000  351481.000000
# unique      120            NaN            NaN            NaN            NaN
# top     10:55.8            NaN            NaN            NaN            NaN
# freq       2930            NaN            NaN            NaN            NaN
# mean        NaN     850.427731     146.003360     -12.468786       8.622677
# std         NaN      80.033068      23.630188      21.484598       3.114466
# min         NaN       0.000000       0.000000     -40.338697      -1.152383
# 25%         NaN     829.736274     144.092370     -21.400105       6.708301
# 50%         NaN     850.728944     148.636272     -18.234780       8.833290
# 75%         NaN     870.418217     154.158951     -10.813444      10.634948
# max         NaN    1299.126253     455.528534     240.250304      19.765313

# %% [markdown]
# ## unique values

# %%
df.nunique() # count of unique values in each column
# Out:
# t_stamp           120
# HpPressure     351439
# IpPressure     350561
# LpPressure     351118
# WetBulbTemp    350846
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index              128
# t_stamp        2811848
# HpPressure     2811848
# IpPressure     2811848
# LpPressure     2811848
# WetBulbTemp    2811848
# dtype: int64

# %% [markdown]
# ## correlation

# %%
columns = ['HpPressure', 'IpPressure', 'LpPressure', 'WetBulbTemp']

print(df[columns].corr())
# Out:
#              HpPressure  IpPressure  LpPressure  WetBulbTemp
# HpPressure     1.000000   -0.155996   -0.452520     0.293070
# IpPressure    -0.155996    1.000000    0.283711     0.042730
# LpPressure    -0.452520    0.283711    1.000000    -0.103768
# WetBulbTemp    0.293070    0.042730   -0.103768     1.000000

# %%
# Display the plot
plt.show()

# Select the columns for correlation
columns = ['HpPressure', 'IpPressure', 'LpPressure', 'WetBulbTemp']

# Calculate the correlation matrix
correlation_matrix = df[columns].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
